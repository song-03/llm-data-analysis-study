# %% [markdown]
# # 1장. AI와 함께하는 데이터 분석의 시작
#
# LLM 기반 데이터 분석 실무 입문 과정의 실습 노트북입니다.

# %% [markdown]
# ## 학습 목표
#
# - 주요 개념과 분석 흐름을 이해합니다.
# - 제공된 실습 데이터를 불러와 기본 구조를 확인합니다.
# - LLM을 분석 보조 도구로 활용하는 방법을 익힙니다.

# %% [markdown]
# ## 실습 배경
#
# 이번 장의 내용을 실습하면서 데이터 로드, 탐색, 전처리, 시각화의 기본 흐름을 확인합니다.

# %%
# %pip install pandas numpy matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.5.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\song\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.64.0-cp312-cp312-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\song\miniconda3\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\song\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.8 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/9.8 MB 9.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 10.7 MB/s eta 0:00:00
# Downloading numpy-2.5.2-cp312-cp312-win_amd64.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.5 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.5 MB 12.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.5 MB 12.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.5 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 12.2 MB/s eta 0:00:00
# Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.4/9.3 MB 12.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.0/9.3 MB 12.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.3 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 12.1 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 11.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.2 MB 12.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 12.1 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 numpy-2.5.2 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

DATA_DIR = Path('../data/raw')
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 데이터 불러오기 기본 설정
#
# 샘플 데이터를 불러오기 위한 기본 설정입니다. 필요에 따라 아래 코드를 수정해 실행합니다.

# %%
# 예시: 필요한 데이터 파일을 읽고 처음 몇 행을 확인합니다.
# customers = pd.read_csv(DATA_DIR / 'customers.csv')
# customers.head()

# %% [markdown]
# ## 실습 진행
#
# 이제 데이터를 직접 다루며 간단한 분석 결과를 확인합니다. 필요한 코드를 자유롭게 추가하세요.

# %% [markdown]
# ## LLM 프롬프트 활용 예시
#
# 이번에는 LLM에게 분석 질문이나 코드 초안을 요청하는 연습을 할 수 있습니다. API Key는 노트북에 직접 입력하지 않습니다.
#
# ```text
# 분석 목적을 설명하고 필요한 코드를 요청하세요.
# ```

# %% [markdown]
# ## 실습 과제
#
# 1. 이번 장에서 배운 내용을 바탕으로 분석 질문 3개를 작성합니다.
# 2. 그중 하나를 pandas 코드로 구현합니다.
# 3. 결과를 표 또는 그래프로 확인하고, LLM 도움을 받아 해석합니다.
